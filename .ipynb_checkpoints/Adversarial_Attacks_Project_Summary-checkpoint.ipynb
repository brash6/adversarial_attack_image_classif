# %% [markdown]
# ![title](presentation_images/logo_dauphine.png)

# %% [markdown]
# # Adversarial Attack Project

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Some-function-imports" data-toc-modified-id="Some-function-imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Some function imports</a></span></li><li><span><a href="#Import-data" data-toc-modified-id="Import-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import data</a></span></li><li><span><a href="#Show-some-data" data-toc-modified-id="Show-some-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Show some data</a></span></li><li><span><a href="#Show-results-of-our-simple-CNN-on-these-data" data-toc-modified-id="Show-results-of-our-simple-CNN-on-these-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Show results of our simple CNN on these data</a></span></li><li><span><a href="#Show-the-effect-of-an-attack-on-data" data-toc-modified-id="Show-the-effect-of-an-attack-on-data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Show the effect of an attack on data</a></span><ul class="toc-item"><li><span><a href="#Let's-take-one-random-image" data-toc-modified-id="Let's-take-one-random-image-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Let's take one random image</a></span></li><li><span><a href="#How-to-noise-this-image-?" data-toc-modified-id="How-to-noise-this-image-?-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>How to noise this image ?</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Some function imports

# %%
import os
import sys
import random 
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
cwd = os.path.join(os.getcwd())
sys.path.append(cwd)
import constants as cst
import import_data
import models
import attack_function
import visualization

# %% [markdown]
# ## Import data

# %%
x_train, y_train, x_test, y_test = import_data.format_data()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Show some data

# %%
visualization.show_data(x_train, y_train)

# %% [markdown]
# ## Show results of our simple CNN on these data

# %%
model = load_model(cst.STANDARD_trained_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d563b1a4dc98> in <module>
# ----> 1 model = load_model(str(cst.STANDARD_trained_model))
#
# c:\users\hma11\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     135   if (h5py is not None and (
#     136       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 137     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     138
#     139   if isinstance(filepath, six.string_types):
#
# c:\users\hma11\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     160     model_config = json.loads(model_config.decode('utf-8'))
# ...

# %% [markdown]
# ## Show the effect of an attack on data

# %% [markdown]
# ### Let's take one random image

# %%
r1 = random.randint(0, 50000)
visualization.show_one_image(x_train, y_train, r1)

# %% [markdown]
# ### How to noise this image ?
